# %% [markdown]
# Lab Report:

# %%
# i. Total power consumed by components

power_readings = [50, 30, 20]   
total_power = sum(power_readings)

# %%
print("Total Power Consumed:", total_power)
# Out:
# Total Power Consumed: 100

# %%
# ii. Equivalent resistance of resistors in series

resistances = [10, 15, 25]      
equivalent_resistance = sum(resistances)

# %%
print("Equivalent Resistance:", equivalent_resistance)
# Out:
# Equivalent Resistance: 50
