# %% [markdown]
# Lab Report:

# %% [markdown]
# Task 1:

# %%
# Adjusted voltage metric
adjusted_voltage = lambda V: V**2 + 2

# %%
# Test
print(adjusted_voltage(5))
# Out:
# 27

# %% [markdown]
# Task 2:

# %%
# Equivalent parallel resistance
parallel_resistance = lambda R1, R2: 1 / (1/R1 + 1/R2)

# %%
# Test
print(parallel_resistance(100, 200))
# Out:
# 66.66666666666667
