# %% [markdown]
# Lab Report:

# %%
# List of current readings (in amperes)
currents = [1.2, 2.0, 2.5, 3.0]

# %%
# Loop through the list and print I^2 for each value
for I in currents:
    print(I ** 2)
# Out:
# 1.44
# 4.0
# 6.25
# 9.0
